# %%
## Archibo de prueba
### Andres Guarin
### 000514479
### andres.guarina@upb.edu.co

# %%
name = "andres"
#name = input("what´s your name")
print("hello, ", name, "nice to meet you")
# Out:
# hello,  andres nice to meet you

# %%
# lista vacia 
junk_food = []
#print(junk_food)

#agregndo elementos 
junk_food.append("hot dog")
#print(junk_food)
junk_food.append("burguer")
junk_food.append("pizza")
#print(junk_food)
#print(type(junk_food))
snacks = ["deTodito","doritos","takis"]
#print(snacks)
junk_food += snacks
#print(junk_food)

# accediendo a los elementos
#print(junk_food)
#print(junk_food[0])
#print(junk_food[1])
#print(junk_food[-1])
#print(junk_food[-2])

#slicing
#print(junk_food[1:-2])
#print(junk_food[1:4])
#print(junk_food[:3])
#print(junk_food[3:])
#print(junk_food[-4:])
#print(junk_food[:-2])

#Modificar elementos
junk_food[-1] = "yupi"
junk_food[0] = "suizo"
#print(junk_food)

# Remover elementos
#junk_food.remove("deTodito")
junk_food.remove("deTodito")
#print(junk_food)

# insertar elementos
junk_food.insert(-1, "quipitos")
junk_food.insert(2, "choclitos")
#print(junk_food)

# pop
junk_food.pop()
junk_food.pop()
junk_food.pop(1)
#print(junk_food)

# range y len
#print(list(range(10)))
#print(list(range(3, 10)))
#print(list(range(3, 10, 2)))# de 3 a 10 en intervalos de 2 hacia adelante
#print(list(range(5, -10, -3))) # de 5 a 10 en intervalos de 3 hacia atras
#print(len(junk_food))
#print(list(range(len(junk_food))))

# contar
junk_food.append("pizza")
junk_food.append("pizza")
junk_food.append("doritos")
junk_food.append("hot dog")
#print(junk_food)
#print(junk_food.count("pizza"))
#print(junk_food.count("burguer"))

# ordenar
sorted_junk_food = sorted(junk_food)
#junk_food.sort()
#print(junk_food)
#print(sorted_junk_food)

# ciclos for
#print(junk_food)
#for food in junk_food:
#   print("-", food)

# for loops
#for i in range(len(junk_food)): # un rango sin tener la lista de junk foood <iteracion>
    #pass 
#    print(i, "-", junk_food[i])

# while
#index = 0
#while index < len(junk_food):
#    print(index, "-", junk_food[index])
#    index += 1
    
    
# break
#print(junk_food)
#request = "doritos"

#for food in junk_food:
#    print(food)
#    if food == request:
#        print("encontrado")
#        break

# continue
#print(junk_food)
#request = "doritos"

#for food in junk_food:
#    print(food)
#    if food == request:
#        continue
#    else:
#        print(food)

# list comprehension
#print(junk_food)
#print(len(junk_food[2]))
#for food in junk_food:
#    print(len(food))

#cant_letras = [len(food) for food in junk_food] # contar las letras 
#cant_letras = [len(food) for food in junk_food if food != "doritos"]
#cant_letras = [len(food)if food != "pizza" else 0  for food in junk_food ]
#print(cant_letras)
